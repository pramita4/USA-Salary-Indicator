# %%
#load necessary libraries
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup
import requests
import csv

# %%
#URLs can be fetched using the Python module urllib.request.

link = 'https://www.bls.gov/oes/current/oes_nat.htm#'
page = urllib.request.urlopen(link)
soup=BeautifulSoup(page)
#print (soup.prettify) #can be used to structure the data

# %%
#get the data using Request and parse it
page = "https://www.bls.gov/oes/current/oes_nat.htm#"
data = requests.get(page)
soup = BeautifulSoup(data.content, "html.parser")
#print (soup)

# %%
#view any required HTML tag content
print ("Page title is \n",soup.title)
#print ("Tables in the page are \n",soup.find_all('table'))
# Out:
# Page title is
#  <title>May 2021 National Occupational Employment and Wage Estimates</title>

# %%
#Get all links in the page
allinks=soup.find_all("a")
for link in allinks:
    links=link.get("href")

# %%
table=soup.find_all('table',class_='main_table_countries')

# %%
thead = soup.table.find('thead')
#print(thead)

# get all the rows in table head
head = thead.find_all('tr')
#print(head)

# get the table body content

tbody = soup.table.find('tbody')
#print(tbody)

# get all the rows in table body

body = tbody.find_all('tr')
#print(body

# %%
body
# Out:
# [<tr>
#  <td class="bold">00-0000</td>
#  <td class="bold" id="00-0000">All Occupations</td>
#  <td>total</td>
#  <td>140,886,310</td>
#  <td>0.0%</td>
#  <td>1000.000</td>
#  <td>$22.00</td>
#  <td>$28.01</td>
#  <td>$58,260</td>
#  <td>0.1%</td>
#  </tr>,
#  <tr>
#  <td class="bold">11-0000</td>
#  <td class="bold" id="11-0000"><a href="oes110000.htm">Management Occupations</a></td>
#  <td>major</td>
#  <td>8,909,910</td>
#  <td>0.2%</td>
#  <td>63.242</td>
#  <td>$49.25</td>
#  <td>$59.31</td>
#  <td>$123,370</td>
#  <td>0.3%</td>
#  </tr>,
#  <tr>
#  <td>11-1000</td>
#  <td id="11-1000">Top Executives</td>
#  <td>minor</td>
#  <td>3,229,990</td>
#  <td>0.4%</td>
#  <td>22.926</td>
#  <td>$47.46</td>
#  <td>$57.94</td>
#  <td>$120,520</td>
#  <td>0.4%</td>
#  </tr>,
#  <tr>
#  <td>11-1011</td>
#  <td><a href="oes111011.htm">Chief Executives</a></td>
#  <td>detail</td>
#  <td>200,480</td>
#  <td>1.6%</td>
#  <td>1.423</td>
#  <td>$86.31</td>
#  <td>$102.41</td>
# ...

# %%
#iterate over the table contents and store it in list

# column title
head_column = []
# table contents
rowvalues = []

# loop through the head and append each row to head
for tr in head:
    td = tr.find_all(['th', 'td'])
    row = [i.text for i in td]
    head_column.append(row)
#print(head_column)

# loop through the body and append each row to body
for tr in body:
    td = tr.find_all(['th', 'td'])
    row = [i.text for i in td]
    rowvalues.append(row)
#print(rowvalues)

# %%
#Store the list content in a DataFrame

jobs = pd.DataFrame(rowvalues,columns=head_column[0])         

jobs.head(15)
# Out:
#    Occupation code  \
# 0          00-0000
# 1          11-0000
# 2          11-1000
# 3          11-1011
# 4          11-1021
# 5          11-1031
# 6          11-2000
# 7          11-2011
# 8          11-2020
# 9          11-2021
# 10         11-2022
# 11         11-2030
# 12         11-2032
# 13         11-2033
# 14         11-3000
#
#    Occupation title (click on the occupation title to view its profile)  \
# 0                                     All Occupations
# 1                              Management Occupations
# 2                                      Top Executives
# 3                                    Chief Executives
# 4                     General and Operations Managers
# 5                                         Legislators
# 6   Advertising, Marketing, Promotions, Public Rel...
# 7                 Advertising and Promotions Managers
# 8                        Marketing and Sales Managers
# 9                                  Marketing Managers
# ...

# %%
df = pd.DataFrame(jobs)
file_name = df.to_csv('jobs.csv')

# %%
df.dtypes
# Out:
# Occupation code                                                         object
# Occupation title (click on the occupation title to view its profile)    object
# Level                                                                   object
# Employment                                                              object
# Employment RSE                                                          object
# Employment per 1,000 jobs                                               object
# Median hourly wage                                                      object
# Mean hourly wage                                                        object
# Annual mean wage                                                        object
# Mean wage RSE                                                           object
# dtype: object

# %%
df['Employment'].to_string
# Out:
# <bound method Series.to_string of 0       b'140,886,310'
# 1         b'8,909,910'
# 2         b'3,229,990'
# 3           b'200,480'
# 4         b'2,984,920'
#              ...
# 1100         b'10,600'
# 1101         b'16,040'
# 1102        b'126,050'
# 1103         b'12,090'
# 1104         b'22,470'
# Name: Employment, Length: 1105, dtype: bytes6400>

# %%
df.dtypes
# Out:
# Occupation code                                                         object
# Occupation title (click on the occupation title to view its profile)     |S800
# Level                                                                   object
# Employment                                                               |S800
# Employment RSE                                                          object
# Employment per 1,000 jobs                                               object
# Median hourly wage                                                      object
# Mean hourly wage                                                        object
# Annual mean wage                                                        object
# Mean wage RSE                                                           object
# dtype: object

# %%
df['Annual mean wage'].to_string #where the max length is set at 80 bytes,
# df['Occupation title (click on the occupation title to view its profile)'] = df['Occupation title (click on the occupation title to view its profile)'].astype('|S800') #where the max length is set at 80 bytes,
# Out:
# <bound method Series.to_string of 0        $58,260
# 1       $123,370
# 2       $120,520
# 3       $213,020
# 4       $115,250
#           ...
# 1100     $54,400
# 1101     $67,170
# 1102     $42,780
# 1103     $55,330
# 1104     $40,190
# Name: Annual mean wage, Length: 1105, dtype: object>

# %%
# # 
# df.plot(kind='barh', x = 'Occupation title (click on the occupation title to view its profile)', y = 'Employment')
